# %%
# !nvidia-smi
# Out:
# /bin/bash: nvidia-smi: command not found

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#For github data
# %cd /content/
# !pip install sacrebleu=="1.2.11"
# !pip install clang pip install clang==14
# !pip install submitit
# Out:
# /content
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sacrebleu: filename=sacrebleu-1.2.11-py3-none-any.whl size=18623 sha256=0e203b49a5251cc23867b3bb702254135b6caa08aaf19d79d3ff45050a148e7a
#   Stored in directory: /root/.cache/pip/wheels/f2/c3/f7/68727efcac2f3245fc3c3bcd549bc2d0a5db9f3106d1e8b0bf
# ...
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26305 sha256=937abc0bbf62310147639c32e0e4472e7b3c4e9d4396202a5908360a230b1c33
#   Stored in directory: /root/.cache/pip/wheels/7c/d0/9e/1f26ebb66d9e1732e4098bc5a6c2d91f6c9a529838f0284890
# Successfully built sacrebleu typing
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Prepare StackOverflow data

# %%
# %cd /content/drive/MyDrive/PLBART-main/data/stackoverflow/
# Out:
# /content/drive/MyDrive/PLBART-main/data/stackoverflow

# %%
# !pip install py7zr

# %%
import py7zr

# %%
source = '/content/drive/MyDrive/PLBART-main/data/stackoverflow/ru.stackoverflow.com.7z'
with py7zr.SevenZipFile(source, mode='r') as z:
        z.extractall()

# %%
#mute line 223
# !python3 preprocess.py --src_dir /content/drive/MyDrive/PLBART-main/data/stackoverflow/
# Out:
# 930206
# /content/drive/MyDrive/PLBART-main/data/stackoverflow//xml_shards/posts_0.txt
# Processing: 100% 930206/930206 [01:08<00:00, 13575.68it/s]
# 930204
# Processing:   0% 0/930204 [00:00<?, ?it/s]/content/drive/MyDrive/PLBART-main/data/stackoverflow/preprocess.py:97: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(ex['Body'].strip(), features="lxml")
# Processing:   1% 8871/930204 [00:01<01:52, 8190.54it/s]/content/drive/MyDrive/PLBART-main/data/stackoverflow/preprocess.py:97: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(ex['Body'].strip(), features="lxml")
# ...

# %% [markdown]
# # Prepare GitHub data

# %%
# !pip install gsutil
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !gcloud auth login
# Out:
# Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsdk.cloud.google.com%2Fauthcode.html&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=sg4SKEmtdpxvHhk9oldxsJkOBhNhPv&prompt=consent&access_type=offline&code_challenge=c6htVXxeYGPQbJ9-YH3APpKKc77ydB0MLZXW3YSo6zI&code_challenge_method=S256
#
# Enter authorization code: 4/0AbUR2VNWI1uWM2gyenZ8_LolcgCS_9hd007JC2IWlzUGryrXLD7dWieoSjS8LfXpjdCBhg
#
# You are now logged in as [pada0acc@gmail.com].
# Your current project is [None].  You can change this setting by running:
# ...

# %%
# !gsutil -m cp -r gs://gc-bigquery-github-data-kate/python /content/drive/MyDrive/PLBART-main/data/github

# %%
# !gsutil du -sh -a gs://gc-bigquery-github-data-kate/python
# Out:
# 13.19 GiB    gs://gc-bigquery-github-data-kate/python

# %%
#data/github/preprocessing/src/code_tokenizer.py
#line 150-153 add return []
#line 138-139 add return []
#line 156-157 add return []
#line 226-229 add return []
#line 130-133 add return []

# was used last 250 jsons

# %cd /content/drive/MyDrive/PLBART-main/data/github/
# !python -m preprocessing.preprocess \
    /content/drive/MyDrive/PLBART-main/data/github \
    --lang1 python
# Out:
# /content/drive/MyDrive/PLBART-main/data/github
# python: process ...
# python: tokenizing 0 json files ...
# python: split train, test and valid ...
# python: train for is 4043958 lines and 28.711032785475254 Go.
# extract functions ...
# extacting functions for /content/drive/MyDrive/PLBART-main/data/github/python/train.0.tok
#   2% 12142/505244 [00:03<02:13, 3699.97it/s]['def', "'", ')', ')', '!=', "'", 'asdfdef', "'", ':', 'NEW_LINE', 'INDENT', 'raise', 'TestFailed', ',', "'", 'concatenation', '▁', 'of', '▁', 'buffers', '▁', 'yields', '▁', 'wrong', '▁', 'content', "'", 'NEW_LINE', 'DEDENT']
#   9% 45667/505244 [00:12<02:13, 3430.37it/s]['def', '__name__', '==', "'", '_', '_', 'main', '_', '_', "'", ':', 'NEW_LINE', 'INDENT', 'image', '=', '"', 'test_suprime', '.', 'fits', "'", 'NEW_LINE', 'DEDENT']
#  12% 61584/505244 [00:17<02:18, 3199.11it/s]['def', 'sum', ':', 'NEW_LINE', 'INDENT', 'c', '=', '5', '+', '3', 'NEW_LINE', 'return', 'c', 'NEW_LINE', 'DEDENT']
# ...
