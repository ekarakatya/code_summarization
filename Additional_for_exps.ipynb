# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !pip install evaluate
# !pip install rouge_score
# !pip install sacrebleu
import evaluate
import json
# Out:
# /content
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: evaluate in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.22.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.4.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.14.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (23.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.18.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (9.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.8.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2022.7.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.22.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.65.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.10/dist-packages (2.3.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2.7.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2022.10.31)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.8.10)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.22.4)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.2)

# %%
import string 
import json

def my_split(x):
  temp = x.split()
  result = []
  for tok in temp:
    accum = ''
    for t in tok: 
      if t not in string.punctuation:
        accum += t
      else:
        if len(accum) > 0:
          result.append(accum)
        accum = ''
        result.append(t)
    if len(accum) > 0:
      result.append(accum)
  return result

# %% [markdown]
# # Env

# %%
# %cd /content

# %env PYTHONPATH=

# !wget https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !chmod +x Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !bash ./Miniconda3-py38_4.12.0-Linux-x86_64.sh -b -f -p /usr/local/

# %%
# !conda install --channel defaults conda python=3.8.10 --yes
# !conda update --channel defaults --all --yes

# %%
import sys
sys.path.append("/usr/local/lib/python3.8/site-packages") #?

# %%
# !yes | bash /content/drive/MyDrive/PLBART-main/install_env.sh

# %% [markdown]
# # Exp (5) (7)

# %%
# %cp /content/drive/MyDrive/PLBART-main/pretrain/plbart_base.pt /content/drive/MyDrive/PLBART-main/scripts/code_to_text/base_python_ru_XX/checkpoint_null.pt

# %%
# %cd /content/drive/MyDrive/PLBART-main/scripts/code_to_text/
# !bash generate.sh 0 python base checkpoint_null.pt test

# %%
# %cd /content/drive/MyDrive/PLBART-main/scripts/code_to_text/
# !bash generate.sh 0 python base checkpoint_null.pt valid
#0.87

# %%
##################

# %%
# %cp /content/drive/MyDrive/PLBART-main/pretrain/plbart_finetuned.pt /content/drive/MyDrive/PLBART-main/scripts/code_to_text/finetuned_python_ru_XX/checkpoint_null.pt

# %%
# %cd /content/drive/MyDrive/PLBART-main/scripts/code_to_text/
# !bash generate.sh 0 python finetuned checkpoint_null.pt test
# Out:
# /content/drive/MyDrive/PLBART-main/scripts/code_to_text
# BLEU Score:	3.03

# %%
# %cd /content/drive/MyDrive/PLBART-main/scripts/code_to_text/
# !bash generate.sh 0 python finetuned checkpoint_null.pt valid

# %% [markdown]
# # Metrics (5)

# %%
# %cd /content
# !pip install evaluate
# !pip install rouge_score
# !pip install sacrebleu
import evaluate
import json

# %%
import string 
import json

def my_split(x):
  temp = x.split()
  result = []
  for tok in temp:
    accum = ''
    for t in tok: 
      if t not in string.punctuation:
        accum += t
      else:
        if len(accum) > 0:
          result.append(accum)
        accum = ''
        result.append(t)
    if len(accum) > 0:
      result.append(accum)
  return result

# %%
references = []
with open('/content/drive/MyDrive/mCoNaLa/mconala_final', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(my_split(line.strip().replace('`', '').lower()))
    #t = line.strip().replace('`', '').lower()
    references.append(t)

# %%
references

# %%
assert len(references) == 345

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/base_python_ru_XX_5/output_checkpoint6.pt_test.hyp'

predictions = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     # pred = " ".join(my_split(line.strip().lower()))
     pred = line.strip().lower()
     predictions.append(pred)

assert len(predictions) == 345


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions, references=references)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions,
                        references=references,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions,
                      references=references,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions,
                      references=references,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.014464798404601189, 'precisions': [0.11635670004768717, 0.03995433789954338, 0.019189765458422176, 0.0037418147801683817], 'brevity_penalty': 0.6017769703859418, 'length_ratio': 0.6631878557874763, 'translation_length': 2097, 'reference_length': 3162}
# {'rougeL': 0.06914326089674455}
# Downloading builder script:   0%|          | 0.00/9.01k [00:00<?, ?B/s]
# {'score': 11.558650669536213, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 42.04400225370694, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/base_python_ru_XX_5/output_checkpoint6.pt_test.hyp'

predictions = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions.append(pred)

assert len(predictions) == 345


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions, references=references)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions,
                        references=references,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions,
                      references=references,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions,
                      references=references,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.014102638435398919, 'precisions': [0.11969480209823558, 0.03995433789954338, 0.019189765458422176, 0.0037418147801683817], 'brevity_penalty': 0.5825759822213463, 'length_ratio': 0.6492260061919505, 'translation_length': 2097, 'reference_length': 3230}
# {'rougeL': 0.08810608936595915}
# {'score': 11.558650669536213, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 42.04400225370694, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %%
references_v = []
with open('/content/drive/MyDrive/PLBART-main/data/codeXglue/code-to-text/python/valid.jsonl', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(json.loads(line)['docstring_tokens'])
    references_v.append(t)

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/base_python_ru_XX_5/output_checkpoint6.pt_valid.hyp'

predictions = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions.append(pred)


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions, references=references_v)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions,
                        references=references_v,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions,
                      references=references_v,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions,
                      references=references_v,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.005248915106582708, 'precisions': [0.1704870924747852, 0.013590395386968627, 0.0032517970457358013, 0.000654632342110862], 'brevity_penalty': 0.6263375183342161, 'length_ratio': 0.6812611487117401, 'translation_length': 105791, 'reference_length': 155287}
# {'rougeL': 0.14769794912907006}
# {'score': 12.757202965169471, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 41.230381093767434, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/base_python_ru_XX_5/output_checkpoint6.pt_valid.hyp'

predictions_v = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     #pred = " ".join(my_split(line.strip().lower()))
     pred = line.strip().lower()
     predictions_v.append(pred)


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions_v, references=references_v)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions_v,
                        references=references_v,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.005248886167063971, 'precisions': [0.17049353890364602, 0.013590993628190032, 0.003251968296600574, 0.0006546751992667638], 'brevity_penalty': 0.6263027558789784, 'length_ratio': 0.6812353899553729, 'translation_length': 105787, 'reference_length': 155287}
# {'rougeL': 0.14763433391665692}
# {'score': 12.757202965169471, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 41.230381093767434, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %% [markdown]
# # Metrics (7)

# %%
references = []
with open('/content/drive/MyDrive/mCoNaLa/mconala_final', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(my_split(line.strip().replace('`', '').lower()))
    #t = line.strip().replace('`', '').lower()
    references.append(t)

assert len(references) == 345

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/finetuned_python_ru_XX_7/output_checkpoint8.pt_test.hyp'

predictions = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions.append(pred)

assert len(predictions) == 345


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions, references=references)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions,
                        references=references,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions,
                      references=references,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions,
                      references=references,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.01241500776769537, 'precisions': [0.16010498687664043, 0.04070066975785677, 0.011904761904761904, 0.001597444089456869], 'brevity_penalty': 0.6616964377554501, 'length_ratio': 0.7077399380804954, 'translation_length': 2286, 'reference_length': 3230}
# {'rougeL': 0.1236892649067998}
# {'score': 17.87566580833674, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 49.48046187141262, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %%
references_v = []
with open('/content/drive/MyDrive/PLBART-main/data/codeXglue/code-to-text/python/valid.jsonl', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(json.loads(line)['docstring_tokens'])
    references_v.append(t)

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/finetuned_python_ru_XX_7/output_checkpoint8.pt_valid.hyp'

predictions_v = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions_v.append(pred)


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions_v, references=references_v)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions_v,
                        references=references_v,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.020256000353671477, 'precisions': [0.25860632981676845, 0.05030370732388466, 0.017389467755561813, 0.006445065607919241], 'brevity_penalty': 0.5829287857601052, 'length_ratio': 0.6494812830436546, 'translation_length': 100856, 'reference_length': 155287}
# {'rougeL': 0.21408745424664366}
# {'score': 21.134230261071213, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 49.15164558556382, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %% [markdown]
# # Metrics (9)

# %%
import string 
import json

def my_split(x):
  temp = x.split()
  result = []
  for tok in temp:
    accum = ''
    for t in tok: 
      if t not in string.punctuation:
        accum += t
      else:
        if len(accum) > 0:
          result.append(accum)
        accum = ''
        result.append(t)
    if len(accum) > 0:
      result.append(accum)
  return result

# %%
references = []
with open('/content/drive/MyDrive/mCoNaLa/mconala_final', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(my_split(line.strip().replace('`', '').lower()))
    #t = line.strip().replace('`', '').lower()
    references.append(t)

assert len(references) == 345

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/base_python_ru_XX_9/output_checkpoint7.pt_test.hyp'

predictions = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions.append(pred)

assert len(predictions) == 345


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions, references=references)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions,
                        references=references,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions,
                      references=references,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions,
                      references=references,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.019978206185931255, 'precisions': [0.14776785714285715, 0.049604221635883905, 0.02193548387096774, 0.005804311774461028], 'brevity_penalty': 0.6427725912095764, 'length_ratio': 0.6934984520123839, 'translation_length': 2240, 'reference_length': 3230}
# {'rougeL': 0.11193416221027462}
# {'score': 15.987057957611109, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 47.75083702343666, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %%
references_v = []
with open('/content/drive/MyDrive/PLBART-main/data/codeXglue/code-to-text/python/valid.jsonl', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(json.loads(line)['docstring_tokens'])
    references_v.append(t)

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/base_python_ru_XX_9/output_checkpoint8.pt_valid.hyp'

predictions_v = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions_v.append(pred)


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions_v, references=references_v)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions_v,
                        references=references_v,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.0112321565002874, 'precisions': [0.20967299963463645, 0.025697426027368287, 0.007131736226206619, 0.002208357784847268], 'brevity_penalty': 0.658095521880232, 'length_ratio': 0.7050171617714297, 'translation_length': 109480, 'reference_length': 155287}
# {'rougeL': 0.17914982842400845}
# {'score': 17.476248247339864, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 47.95600596280584, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %% [markdown]
# # Metrics (12)

# %%
references = []
with open('/content/drive/MyDrive/mCoNaLa/mconala_final', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(my_split(line.strip().replace('`', '').lower()))
    #t = line.strip().replace('`', '').lower()
    references.append(t)

assert len(references) == 345

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/finetuned_python_ru_XX_12/output_checkpoint9.pt_test.hyp'

predictions = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions.append(pred)

assert len(predictions) == 345


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions, references=references)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions,
                        references=references,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions,
                      references=references,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions,
                      references=references,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.018598997990895254, 'precisions': [0.17644444444444443, 0.047244094488188976, 0.016666666666666666, 0.004918032786885246], 'brevity_penalty': 0.6469051754643524, 'length_ratio': 0.6965944272445821, 'translation_length': 2250, 'reference_length': 3230}
# {'rougeL': 0.13481693058277333}
# {'score': 19.175448437260407, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 50.20522236923824, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %%
references_v = []
with open('/content/drive/MyDrive/PLBART-main/data/codeXglue/code-to-text/python/valid.jsonl', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(json.loads(line)['docstring_tokens'])
    references_v.append(t)

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/finetuned_python_ru_XX_12/output_checkpoint10.pt_valid.hyp'

predictions_v = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions_v.append(pred)


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions_v, references=references_v)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions_v,
                        references=references_v,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.024725004462724548, 'precisions': [0.27067435135352236, 0.05943973356638401, 0.022248982166408623, 0.00977679059097695], 'brevity_penalty': 0.5716481123005819, 'length_ratio': 0.6413415160316059, 'translation_length': 99592, 'reference_length': 155287}
# {'rougeL': 0.2194990574031574}
# {'score': 22.50345043029335, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 50.1677961505202, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %% [markdown]
# # Metrics (11)

# %%
references = []
with open('/content/drive/MyDrive/mCoNaLa/mconala_final', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(my_split(line.strip().replace('`', '').lower()))
    #t = line.strip().replace('`', '').lower()
    references.append(t)

assert len(references) == 345

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/base_python_ru_XX_11/output_checkpoint9.pt_test.hyp'

predictions = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions.append(pred)

assert len(predictions) == 345


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions, references=references)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions,
                        references=references,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions,
                      references=references,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions,
                      references=references,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.022678933334918727, 'precisions': [0.1492098493201029, 0.045875420875420875, 0.017232890201871, 0.004739336492890996], 'brevity_penalty': 0.8293910023887646, 'length_ratio': 0.8424148606811146, 'translation_length': 2721, 'reference_length': 3230}
# {'rougeL': 0.1325747130916642}
# {'score': 18.457169745168496, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 51.14788194718689, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %%
references_v = []
with open('/content/drive/MyDrive/PLBART-main/data/codeXglue/code-to-text/python/valid.jsonl', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(json.loads(line)['docstring_tokens'])
    references_v.append(t)

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/base_python_ru_XX_11/output_checkpoint12.pt_valid.hyp'

predictions_v = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions_v.append(pred)


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions_v, references=references_v)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions_v,
                        references=references_v,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.024230772713728685, 'precisions': [0.2770072541422801, 0.06017289662729819, 0.02268940070225555, 0.010051787727646238], 'brevity_penalty': 0.5487539575790381, 'length_ratio': 0.6249589469820397, 'translation_length': 97048, 'reference_length': 155287}
# {'rougeL': 0.22245474254821568}
# {'score': 22.052448790658293, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 49.44527619614611, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %% [markdown]
# # Metrics (6)

# %%
references = []
with open('/content/drive/MyDrive/mCoNaLa/mconala_final', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(my_split(line.strip().replace('`', '').lower()))
    #t = line.strip().replace('`', '').lower()
    references.append(t)

assert len(references) == 345

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/finetuned_python_ru_XX_6/output_checkpoint4.pt_test.hyp'

predictions = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions.append(pred)

assert len(predictions) == 345


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions, references=references)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions,
                        references=references,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions,
                      references=references,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions,
                      references=references,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.003142658373034468, 'precisions': [0.07066993464052287, 0.006181645268663814, 0.0011370096645821489, 0.0007047216349541931], 'brevity_penalty': 0.7265525652861898, 'length_ratio': 0.7578947368421053, 'translation_length': 2448, 'reference_length': 3230}
# {'rougeL': 0.05636299645346736}
# {'score': 10.055544229260924, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 41.17122677089762, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %%
references_v = []
with open('/content/drive/MyDrive/PLBART-main/data/codeXglue/code-to-text/python/valid.jsonl', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(json.loads(line)['docstring_tokens'])
    references_v.append(t)

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/finetuned_python_ru_XX_6/output_checkpoint16.pt_valid.hyp'

predictions_v = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions_v.append(pred)


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions_v, references=references_v)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions_v,
                        references=references_v,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.006887024323262448, 'precisions': [0.172388682663446, 0.014331340594545902, 0.003564007152177065, 0.0011636813575300496], 'brevity_penalty': 0.6845253938050843, 'length_ratio': 0.7251476298724298, 'translation_length': 112606, 'reference_length': 155287}
# {'rougeL': 0.1468941135087642}
# {'score': 15.538448829471536, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 49.059853674486845, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %% [markdown]
# # Metrics (8)

# %%
references = []
with open('/content/drive/MyDrive/mCoNaLa/mconala_final', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(my_split(line.strip().replace('`', '').lower()))
    #t = line.strip().replace('`', '').lower()
    references.append(t)

assert len(references) == 345

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/base_python_ru_XX_8/output_checkpoint8.pt_test.hyp'

predictions = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions.append(pred)

assert len(predictions) == 345


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions, references=references)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions,
                        references=references,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions,
                      references=references,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions,
                      references=references,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.019389472939555646, 'precisions': [0.16621004566210046, 0.04552845528455285, 0.020666666666666667, 0.0060396893874029335], 'brevity_penalty': 0.6219560519619992, 'length_ratio': 0.6780185758513931, 'translation_length': 2190, 'reference_length': 3230}
# {'rougeL': 0.12001307262192024}
# {'score': 17.330259586474195, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 49.22570863903403, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %%
references_v = []
with open('/content/drive/MyDrive/PLBART-main/data/codeXglue/code-to-text/python/valid.jsonl', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(json.loads(line)['docstring_tokens'])
    references_v.append(t)

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/base_python_ru_XX_8/output_checkpoint10.pt_valid.hyp'

predictions_v = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions_v.append(pred)


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions_v, references=references_v)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions_v,
                        references=references_v,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.01913377245914357, 'precisions': [0.24826573399547835, 0.04600153526596225, 0.015108528920683617, 0.005747126436781609], 'brevity_penalty': 0.6063314494976505, 'length_ratio': 0.6665207003805856, 'translation_length': 103502, 'reference_length': 155287}
# {'rougeL': 0.2068758415372096}
# {'score': 20.835447799081734, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 49.74813539748666, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %% [markdown]
# # Metrics (10)

# %%
references = []
with open('/content/drive/MyDrive/mCoNaLa/mconala_final', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(my_split(line.strip().replace('`', '').lower()))
    #t = line.strip().replace('`', '').lower()
    references.append(t)

assert len(references) == 345

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/finetuned_python_ru_XX_10/output_checkpoint5.pt_test.hyp'

predictions = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions.append(pred)

assert len(predictions) == 345


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions, references=references)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions,
                        references=references,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions,
                      references=references,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions,
                      references=references,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.01213241159128543, 'precisions': [0.14181486548107616, 0.038419913419913417, 0.015302727877578177, 0.0017226528854435831], 'brevity_penalty': 0.6232121945051228, 'length_ratio': 0.6789473684210526, 'translation_length': 2193, 'reference_length': 3230}
# {'rougeL': 0.10499445693089801}
# {'score': 14.989183216016237, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 45.718353044240025, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %%
references_v = []
with open('/content/drive/MyDrive/PLBART-main/data/codeXglue/code-to-text/python/valid.jsonl', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(json.loads(line)['docstring_tokens'])
    references_v.append(t)

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/finetuned_python_ru_XX_10/output_checkpoint9.pt_valid.hyp'

predictions_v = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions_v.append(pred)


bleu = evaluate.load("bleu", max_order=4, smooth=True) #Нужно учитывать регистр букв!
results = bleu.compute(predictions=predictions_v, references=references_v)
print(results)

rouge_l = evaluate.load('rouge')
results = rouge_l.compute(predictions=predictions_v,
                        references=references_v,
                        tokenizer=lambda x: x.split(), 
                        rouge_types=['rougeL'])
print(results)

chrf = evaluate.load("chrf")
results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      lowercase=True)
print(results)

results = chrf.compute(predictions=predictions_v,
                      references=references_v,
                      char_order=1,
                      lowercase=True)
print(results)
# Out:
# {'bleu': 0.011926906657339737, 'precisions': [0.20289046653144016, 0.025618459991102686, 0.006713078070611636, 0.002023604188453233], 'brevity_penalty': 0.7316650975310205, 'length_ratio': 0.7619440133430359, 'translation_length': 118320, 'reference_length': 155287}
# {'rougeL': 0.17902947042388812}
# {'score': 18.571743568835018, 'char_order': 6, 'word_order': 0, 'beta': 2}
# {'score': 50.528588912353115, 'char_order': 1, 'word_order': 0, 'beta': 2}

# %% [markdown]
# # New Section

# %%
references = []
with open('/content/drive/MyDrive/mCoNaLa/mconala_final', 'r', encoding='utf-8') as f:
  for line in f:
    t = " ".join(my_split(line.strip().replace('`', '').lower()))
    #t = line.strip().replace('`', '').lower()
    references.append(t)

assert len(references) == 345

# %%
references

# %%
results = '/content/drive/MyDrive/PLBART-main/checkpoints/finetuned_python_ru_XX_12/output_checkpoint9.pt_test.hyp'

predictions = []
with open(results, 'r', encoding='utf-8') as f:
  for line in f:
     pred = " ".join(my_split(line.strip().lower()))
     #pred = line.strip().lower()
     predictions.append(pred)

assert len(predictions) == 345

ref = []
for x in references:
  if x[-1] == '.':
    ref.append(x[:-1])
    continue
  ref.append(x)


pred = []
for x in predictions:
  if x[-1] == '.':
    pred.append(x[:-1])
    continue
  pred.append(x)

sacrebleu = evaluate.load("sacrebleu")
results = sacrebleu.compute(predictions=pred, 
                            references=ref,
                            force=False)
print(results)
# Out:
# {'score': 100.00000000000004, 'counts': [3230, 2885, 2540, 2195], 'totals': [3230, 2885, 2540, 2195], 'precisions': [100.0, 100.0, 100.0, 100.0], 'bp': 1.0, 'sys_len': 3230, 'ref_len': 3230}

# %%
# Out:
# {'score': 1.833622616811023, 'counts': [397, 90, 26, 6], 'totals': [2017, 1672, 1327, 994], 'precisions': [19.682697074863658, 5.382775119617225, 1.9593067068575736, 0.6036217303822937], 'bp': 0.5480503041804029, 'sys_len': 2017, 'ref_len': 3230}

# %%
2.2180239800786565 base 250k

# %%
1.833622616811023
